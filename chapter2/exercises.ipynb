# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Questão 8

# %% [markdown]
# ## Item a)

# %%
college = pd.read_csv("College.csv")

# %%
college.head(5)
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# ## item b)

# %%
college2 = pd.read_csv("College.csv", index_col=0)

# %%
college2.head(5)
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %% [markdown]
# ## item c)

# %%
college2.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ## item d)

# %%
pd.plotting.scatter_matrix(college2[["Top10perc","Apps", "Enroll"]]);

# %% [markdown]
# ## item e)

# %%
college2.boxplot('Outstate', by= 'Private');

# %% [markdown]
# ## item f)

# %%
college2['Elite'] = pd.cut(college2['Top10perc'],
                            2,
                            labels=['No', 'Yes'],
                            ordered=True)

# %%
college2.sort_values(by="Top10perc", ascending=False)
# Out:
#                                       Private   Apps  Accept  Enroll  \
# Massachusetts Institute of Technology     Yes   6411    2140    1078
# University of California at Berkeley       No  19873    8252    3215
# Harvey Mudd College                       Yes   1377     572     178
# Yale University                           Yes  10705    2453    1317
# Duke University                           Yes  13789    3893    1583
# ...                                       ...    ...     ...     ...
# Virginia State University                  No   2996    2440     704
# Morris College                            Yes    882     730     330
# North Adams State College                  No   1563    1005     240
# Center for Creative Studies               Yes    601     396     203
# Fayetteville State University              No   1455    1064     452
#
#                                        Top10perc  Top25perc  F.Undergrad  \
# ...

# %%
college2['Elite'].value_counts()
# Out:
# Elite
# No     687
# Yes     90
# Name: count, dtype: int64

# %% [markdown]
# ## item g)

# %%
college2.head(5)
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
fig, axes = plt.subplots(2, 2)
college2.hist("Apps", bins = 50, ax=axes[0,0])
college2.hist("Books", bins = 30, ax=axes[0,1])
college2.hist("Personal", bins = 100, ax=axes[1,0])
college2.hist("Expend", bins = 25, ax=axes[1,1])
# Out:
# array([<Axes: title={'center': 'Expend'}>], dtype=object)

# %% [markdown]
# # Questão 9

# %%
Auto = pd.read_csv("Auto.csv",
                    na_values=['?'])

# %%
Auto.head(5)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ## item a)

# %%
Auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %% [markdown]
# Quantitativos: mpg, cylinders, displacement, horsepower, weight, acceleration, year
#
# Qualitativos: origin

# %% [markdown]
# ## item b)

# %%
Auto[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'year']].describe().T[['min', 'max']]
# Out:
#                  min     max
# mpg              9.0    46.6
# cylinders        3.0     8.0
# displacement    68.0   455.0
# horsepower      46.0   230.0
# weight        1613.0  5140.0
# acceleration     8.0    24.8
# year            70.0    82.0

# %% [markdown]
# ## item c)

# %%
Auto[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'year']].describe().T[['mean', 'std']]
# Out:
#                      mean         std
# mpg             23.515869    7.825804
# cylinders        5.458438    1.701577
# displacement   193.532746  104.379583
# horsepower     104.469388   38.491160
# weight        2970.261965  847.904119
# acceleration    15.555668    2.749995
# year            75.994962    3.690005

# %% [markdown]
# ## item d)

# %%
new_df = pd.concat([Auto[:10], Auto[86:]])

# %%
new_df[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'year']].describe().T[['min', 'max', 'mean', 'std']]
# Out:
#                  min     max         mean         std
# mpg             11.0    46.6    24.444860    7.899928
# cylinders        3.0     8.0     5.370717    1.653486
# displacement    68.0   455.0   187.174455   99.864568
# horsepower      46.0   230.0   101.003155   36.003208
# weight        1649.0  4997.0  2933.183801  809.638650
# acceleration     8.5    24.8    15.709034    2.706441
# year            70.0    82.0    77.143302    3.128202

# %% [markdown]
# # Questão 10

# %%
import seaborn as sns

# %% [markdown]
# ## item a)

# %%
boston = pd.read_csv("Boston.csv", index_col=0)

# %% [markdown]
# ## item b)

# %%
shape = boston.shape

print(f"O dataframe contém {shape[0]} linhas e {shape[1]} colunas")
# Out:
# O dataframe contém 506 linhas e 13 colunas

# %%
boston.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# lstat      float64
# medv       float64
# dtype: object

# %%
boston.head(5)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 1   4.98  24.0
# 2   9.14  21.6
# 3   4.03  34.7
# 4   2.94  33.4
# 5   5.33  36.2

# %% [markdown]
# A tabela Boston representa uma série de casas na região de Boston, MA com suas respectivas características. Segue descrição das colunas:
#
# CRIM - per capita crime rate by town
#
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
#
# INDUS - proportion of non-retail business acres per town.
#
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#
# NOX - nitric oxides concentration (parts per 10 million)
#
# RM - average number of rooms per dwelling
#
# AGE - proportion of owner-occupied units built prior to 1940
#
# DIS - weighted distances to five Boston employment centres
#
# RAD - index of accessibility to radial highways
#
# TAX - full-value property-tax rate per $10,000
#
# PTRATIO - pupil-teacher ratio by town
#
# B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#
# LSTAT - % lower status of the population
#
# MEDV - Median value of owner-occupied homes in $1000's

# %% [markdown]
# ## item c)

# %%
n_plots = len(boston.columns) - 1
fig, axes = plt.subplots(nrows=n_plots, ncols=1, figsize=(4, 5*n_plots))

for i, col in enumerate(boston.columns[1:]):
    ax = axes[i]
    ax.scatter(boston['medv'], boston[col], alpha=0.7)
    ax.set_xlabel('medv')
    ax.set_ylabel(col)
    ax.set_title(f'{col} vs medv')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## item d)

# %%
col_to_plot = 'crim'
n_plots = len(boston.columns) - 1
fig, axes = plt.subplots(nrows=n_plots, ncols=1, figsize=(4, 5*n_plots))

for i, col in enumerate(boston.columns[1:]):
    ax = axes[i]
    ax.scatter(boston[col_to_plot], boston[col], alpha=0.7)
    ax.set_xlabel(col_to_plot)
    ax.set_ylabel(col)
    ax.set_title(f'{col} vs {col_to_plot}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## item e)

# %% [markdown]
# Altas taxas de crime:

# %%
plt.boxplot(boston['crim']);

# %%
boston[ boston['crim'] > 30]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 381  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666
# 399  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  41.5292  0.0   18.1     0  0.693  5.531   85.4  1.6074   24  666
# 406  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 411  51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24  666
# 415  45.7461  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666
# 419  73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24  666
# 428  37.6619  0.0   18.1     0  0.679  6.202   78.7  1.8629   24  666
#
#      ptratio  lstat  medv
# 381     20.2  17.21  10.4
# 399     20.2  30.59   5.0
# 405     20.2  27.38   8.5
# 406     20.2  22.98   5.0
# 411     20.2  10.11  15.0
# 415     20.2  36.98   7.0
# 419     20.2  20.62   8.8
# 428     20.2  14.52  10.9

# %% [markdown]
# Taxas:

# %%
plt.boxplot(boston['tax']);

# %% [markdown]
# Proporção professor-pupilo:

# %%
plt.boxplot(boston['ptratio']);

# %% [markdown]
# ## item f)

# %%
boston[boston['chas'] == 1].shape[0]
# Out:
# 35

# %% [markdown]
# ## item g)
#
# 19.05

# %%
boston[['ptratio']].describe()
# Out:
#           ptratio
# count  506.000000
# mean    18.455534
# std      2.164946
# min     12.600000
# 25%     17.400000
# 50%     19.050000
# 75%     20.200000
# max     22.000000
